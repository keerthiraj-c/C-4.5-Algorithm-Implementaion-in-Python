# %% [markdown]
# # ChefBoost is a lightweight decision tree framework for Python with categorical feature support
#
# # It handles decision tree algorithms: ID3, C4.5, CART, CHAID and regression tree

# %%
#pip install chefboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from chefboost import Chefboost as chef

# %%
df = pd.DataFrame({"toothed":["True","True","True","False","True","True","True","True","True","False"],
                     "hair":["True","True","False","True","True","True","False","False","True","False"],
                     "breathes":["True","True","True","True","True","True","False","True","True","True"],
                     "legs":["True","True","False","True","True","True","False","False","True","True"],
                     "species":["Mammal","Mammal","Reptile","Mammal","Mammal","Mammal","Reptile","Reptile","Mammal","Reptile"]}, 
                    columns=["toothed","hair","breathes","legs","species"])

features = df[["toothed","hair","breathes","legs"]]
target = df["species"]

df
# Out:
#   toothed   hair breathes   legs  species
# 0    True   True     True   True   Mammal
# 1    True   True     True   True   Mammal
# 2    True  False     True  False  Reptile
# 3   False   True     True   True   Mammal
# 4    True   True     True   True   Mammal
# 5    True   True     True   True   Mammal
# 6    True  False    False  False  Reptile
# 7    True  False     True  False  Reptile
# 8    True   True     True   True   Mammal
# 9   False  False     True   True  Reptile

# %%
df
# Out:
#   toothed   hair breathes   legs  species
# 0    True   True     True   True   Mammal
# 1    True   True     True   True   Mammal
# 2    True  False     True  False  Reptile
# 3   False   True     True   True   Mammal
# 4    True   True     True   True   Mammal
# 5    True   True     True   True   Mammal
# 6    True  False    False  False  Reptile
# 7    True  False     True  False  Reptile
# 8    True   True     True   True   Mammal
# 9   False  False     True   True  Reptile

# %%
config = {'algorithm': 'ID3'}
model = chef.fit(df, config = config, target_label = 'species')
# Out:
# [INFO]:  1 CPU cores will be allocated in parallel running
# ID3  tree is going to be built...
# -------------------------
# finished in  0.13833880424499512  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  100.0 % on  10  instances
# Labels:  ['Mammal' 'Reptile']
# Confusion matrix:  [[6, 0], [0, 4]]
# Precision:  100.0 %, Recall:  100.0 %, F1:  100.0 %

# %%
df
# Out:
#   toothed   hair breathes   legs  species
# 0    True   True     True   True   Mammal
# 1    True   True     True   True   Mammal
# 2    True  False     True  False  Reptile
# 3   False   True     True   True   Mammal
# 4    True   True     True   True   Mammal
# 5    True   True     True   True   Mammal
# 6    True  False    False  False  Reptile
# 7    True  False     True  False  Reptile
# 8    True   True     True   True   Mammal
# 9   False  False     True   True  Reptile

# %%
prediction = chef.predict(model, param = ['True','True','True','True'])

# %%
prediction
# Out:
# 'Mammal'

# %%
prediction = chef.predict(model, param = ['False','False','True','True'])
prediction
# Out:
# 'Reptile'
